# %% [markdown]
# # Regarding patients dataset

# %%
import pandas as pd
import numpy as np

# %%
# params

path = "../DATA/dades_excels"
path_old = path + "/base de dades estudiants (1).xlsx"
path_new = path + "/base de datos reducida.xlsx"

# %%
df_old = pd.read_excel(path_old)
df_new = pd.read_excel(path_new)

# %%
df_old.head()
# Out:
#    codigo_biobanco  sexo  talla  raza      fecha  vhc  ast2  alt2  \
# 0             2096     0   1.88     1 2010-03-01    2   NaN   NaN
# 1             2221     1   1.62     1 2010-03-01    2  21.0  24.0
# 2             2222     0   1.71     1 2010-03-01    2  21.0  22.0
# 3             2223     1   1.45     1 2010-03-01    2  19.0  12.0
# 4             2225     0   1.75     1 2010-03-01    2  40.0  37.0
#
#    colesterol_total2  colesterol_hdl2                 ...                   \
# 0            191.000          37.8000                 ...
# 1            169.498          67.1814                 ...
# 2            163.706          41.3127                 ...
# 3            189.961          56.7567                 ...
# 4            152.895          62.1621                 ...
#
#    edad_paciente_evento  perdi_segui  mot_perdida_seguimiento  \
# 0                   NaN            2                   9999.0
# 1                   NaN            2                   9999.0
# ...

# %%
df_new.head()
# Out:
#    Códigobiobanco  nºmuestra  ID  Tipoindividuo  Dilución  nºviales_plasma  \
# 0            1801     1131.0  14              1       1.0              1.0
# 1            1802     1132.0  45              1       1.0              NaN
# 2            1803     1133.0  22              1       1.0              1.0
# 3            1804     1134.0  47              1       1.0              NaN
# 4            1805     1135.0  42              1       1.0              NaN
#
#    suero nombre_centro  ciudad fechanacimiento  ...    \
# 0      0          HUAV  Lleida      1936-02-13  ...
# 1      0          HUAV  Lleida      1944-08-28  ...
# 2      0          HUAV  Lleida      1943-08-11  ...
# 3      0          HUAV  Lleida      1946-02-01  ...
# 4      0          HUAV  Lleida      1961-05-29  ...
#
#    DosisdiariadequelantesdelfósforoconcalcioUdia  Aportedecalcioelementogdia  \
# 0                                            NaN                         NaN
# ...

# %%
Names_columns_old=df_old.columns
print("Nombre de categories en les dades veies",len(Names_columns_old),"\n")
for i in Names_columns_old:
    print(i)
# Out:
# Nombre de categories en les dades veies 246
#
# codigo_biobanco
# sexo
# talla
# raza
# fecha
# vhc
# ast2
# alt2
# colesterol_total2
# colesterol_hdl2
# colesterol_ldl2
# trigliceridos2
# glucosa2
# indice_homa
# hematocrito2
# hemoglobina2
# fe2
# tranferrina2
# ferritina2
# ca_total2
# fosforo2
# producto_ca_fosforo
# albumina2
# ca_total_corregido
# urea2
# ac_urico2
# PTHi2
# PTHi_KDOQI
# Apob2
# Apoa12
# insu2
# sodi2
# potasi2
# microalbuminuria2
# catotalcor2
# albucrea2
# microAlbu24h2
# leucos
# plaquetas
# volumplac
# t_comorbilidad_exploracion_numero_visita
# t_comorbilidad_exploracion_tabaco
# t_comorbilidad_exploracion_alcohol
# t_comorbilidad_exploracion_diabetes
# t_comorbilidad_exploracion_hipertenso
# t_comorbilidad_exploracion_dislipemico
# t_comorbilidad_exploracion_fibrilacion_auricular
# t_comorbilidad_exploracion_insuf_cardiaca
# t_comorbilidad_exploracion_paratiroidectomia
# t_comorbilidad_exploracion_antec_CV_prematura
# t_comorbilidad_exploracion_peso
# ...

# %%
Names_columns_new=df_new.columns
print("Nombre de categories en les dades noves",len(Names_columns_new),"\n")
for i in Names_columns_new:
    print(i)
# Out:
# Nombre de categories en les dades noves 261
#
# Códigobiobanco
# nºmuestra
# ID
# Tipoindividuo
# Dilución
# nºviales_plasma
# suero
# nombre_centro
# ciudad
# fechanacimiento
# sexo
# raza
# tallam
# pesoKg
# IMC
# cinturacm
# tabaco
# Tabaquismo_Si_No
# Tabaquismo_3categ
# Ingestaalcoholgdia
# diabetes
# DM
# hipertenso
# HTA
# dislipemico
# fibrilacion_auricular
# insuf_cardiaca
# paratiroidectomia
# antecfamiliarespatologiaCVprematura
# TASmmHg
# TADmmHg
# presiónpulsommHg
# Extracciónbiobancoenayunas
# Paxgene
# Paxgene_RNA
# fechaexploraciónvascular
# Edadfechaexploracionvascular
# Edadcuadratica
# EA_Basal
# GIMmedio
# GIMmedioCC
# GIM_Med_TRUNC
# GIM_Med_CC_TRUNC
# ITB
# ITBpatol
# ITBcalcif
# ITBisque
# gim_med_cc_d
# gim_med_bif_d
# gim_med_car_d
# gim_med_cc_i
# gim_med_bif_i
# gim_med_car_i
# gim_cc_mean
# gim_mean
# gim_median
# gim_med_cc_d_trunc
# gim_med_bif_d_trunc
# gim_med_car_d_trunc
# gim_med_cc_i_trunc
# gim_med_bif_i_trunc
# gim_med_car_i_trunc
# ...

# %%
# categories en new que no estaven en old

for i in Names_columns_new:
    if((i in Names_columns_old)==False):
        print(i)
# Out:
# sexo
# raza
# ITB
# gim_med_cc_d
# gim_med_bif_d
# gim_med_car_d
# gim_med_cc_i
# gim_med_bif_i
# gim_med_car_i
# placas_cc_d
# placas_med_bif_d
# placas_med_car_d
# placas_cc_i
# placas_med_bif_i
# placas_med_car_i
# placas_fem_com_d
# placas_fem_sup_d
# placas_fem_com_i
# placas_fem_sup_i
# area_cc_d
# area_med_bif_d
# area_med_car_d
# area_cc_i
# area_med_bif_i
# area_med_car_i
# area_fem_com_d
# area_fem_sup_d
# area_fem_com_i
# area_fem_sup_i
# lipidos_cc_d
# fibrosis_cc_d
# calcio_cc_d
# lipidos_med_bif_d
# fibrosis_med_bif_d
# calcio_med_bif_d
# lipidos_med_car_d
# fibrosis_med_car_d
# calcio_med_car_d
# lipidos_cc_i
# fibrosis_cc_i
# calcio_cc_i
# lipidos_med_bif_i
# fibrosis_med_bif_i
# calcio_med_bif_i
# lipidos_med_car_i
# fibrosis_med_car_i
# calcio_med_car_i
# lipidos_fem_com_d
# fibrosis_fem_com_d
# calcio_fem_com_d
# lipidos_fem_sup_d
# fibrosis_fem_sup_d
# calcio_fem_sup_d
# lipidos_fem_com_i
# fibrosis_fem_com_i
# calcio_fem_com_i
# lipidos_fem_sup_i
# ...

# %%
# categories en old que no estaven en new

for i in Names_columns_old:
    if((i in Names_columns_new)==False):
        print(i)
# Out:
# codigo_biobanco
# talla
# fecha
# vhc
# ast2
# alt2
# colesterol_total2
# colesterol_hdl2
# colesterol_ldl2
# trigliceridos2
# glucosa2
# indice_homa
# hematocrito2
# hemoglobina2
# fe2
# tranferrina2
# ferritina2
# ca_total2
# fosforo2
# producto_ca_fosforo
# albumina2
# ca_total_corregido
# urea2
# ac_urico2
# PTHi2
# PTHi_KDOQI
# Apob2
# Apoa12
# insu2
# sodi2
# potasi2
# microalbuminuria2
# catotalcor2
# albucrea2
# microAlbu24h2
# leucos
# plaquetas
# volumplac
# t_comorbilidad_exploracion_numero_visita
# t_comorbilidad_exploracion_tabaco
# t_comorbilidad_exploracion_alcohol
# t_comorbilidad_exploracion_diabetes
# t_comorbilidad_exploracion_hipertenso
# t_comorbilidad_exploracion_dislipemico
# t_comorbilidad_exploracion_fibrilacion_auricular
# t_comorbilidad_exploracion_insuf_cardiaca
# t_comorbilidad_exploracion_paratiroidectomia
# t_comorbilidad_exploracion_antec_CV_prematura
# t_comorbilidad_exploracion_peso
# t_comorbilidad_exploracion_imc
# ...

# %%
Names_columns=df.columns

for i in Names_columns:
    if(i[:5]=='gim_m'):
        print(i)
# Out:
# gim_med_cc_d
# gim_med_bif_d
# gim_med_car_d
# gim_med_cc_i
# gim_med_bif_i
# gim_med_car_i
# gim_medio

# %% [markdown]
# CLASIFICACION_PLACAS
#
#     id	nombre
#     1	Tipo 1: Uniformemente hipoecoica, homogénea
#     2	Tipo 2: Predominantemente hipoecoica (>50%), heter.
#     3	Tipo 3: Predominantemente hiperecoica (>50%), heter.
#     4	Tipo 4: Uniformemente hiperecoica, homogénea
#     5	Tipo 5: Calcificada. Sombra acústica sufi. impide valuar
#     99	NS/NC
#
# GRADO_ESTENOSIS placa (=Obstrucción de arteria)
#
#     id	nombre
#     1	No estenosis
#     2	< 50%
#     3	50-69%
#     4	70-99%
#     5	Oclusión
#     99	NS/NC

# %% [markdown]
# ### Patients with Placa

# %%
placa_ccd_counts=df.groupby('placas_cc_d').ones.sum()

print('Patients with ccd placa:'+str((1-placa_ccd_counts[1]/placa_ccd_counts.sum())*100)+'%')
placa_ccd_counts
# Out:
# Patients with ccd placa:6.64893617021%
# placas_cc_d
# 1    702
# 2     49
# 3      1
# Name: ones, dtype: int64

# %%
placa_cci_counts=df.groupby('placas_cc_i').ones.sum()

print('Patients with cci placa:'+str((1-placa_cci_counts[1]/placa_cci_counts.sum())*100)+'%')
placa_cci_counts
# Out:
# Patients with cci placa:9.3085106383%
# placas_cc_i
# 1    682
# 2     65
# 3      4
# 5      1
# Name: ones, dtype: int64

# %%
Df_placas_cci=df[df['placas_cc_i']!=1]
Df_placas_ccd=df[df['placas_cc_d']!=1]

# %%
Df_placas_cci.head()
# Out:
#     codigo_biobanco  sexo  talla  raza      fecha  vhc  ast2  alt2  \
# 7              2338     0   1.63     1 2010-03-01    2   NaN   NaN
# 8              2404     0   1.69     1 2010-03-01    2  14.0  12.0
# 13             2464     0   1.79     1 2010-03-01    2  22.0  24.0
# 19             2230     0   1.72     1 2010-03-02    2  18.0  16.0
# 22             2233     1   1.53     1 2010-03-02    2  24.0  15.0
#
#     colesterol_total2  colesterol_hdl2  ...   perdi_segui  \
# 7             179.000          28.0000  ...             2
# 8             224.000          60.0000  ...             2
# 13            173.000          38.0000  ...             2
# 19            200.772          28.9575  ...             2
# 22            130.115          42.8571  ...             2
#
#     mot_perdida_seguimiento  muerte_paciente  fecha_muerte  causa_muerte  \
# 7                    9999.0              NaN           NaN           0.0
# ...

# %% [markdown]
# #### Number of patients dead by a cardiovascular incident

# %%
Df_placas_cci[Df_placas_cci['causa_muerte']==0].shape[0]
Df_placas_ccd[Df_placas_ccd['causa_muerte']==0].shape[0]
# Out:
# 18

# %% [markdown]
# 21 de 70 que tenien cci!!
#
# 18 de 50 que tenien ccd!!

# %% [markdown]
# ### Dubtes:
#  * vhc:
#
# Virus de la Hepatitis C
#
#  * comorbilidad:
#
# La presencia de uno o más trastornos (o enfermedades) además de la enfermedad o trastorno primario.
# El efecto de estos trastornos o enfermedades adicionales.
#
#  * ITB:
#
# Índice tobillo/brazo.
#
#  * IMC:
#
# Índice masa corporal
#
#  * HDL:
#
# High-density lipoproteins (colesterol "bo")
#
#  * LDL:
#
# Low-density lipoproteins (colesterol "dolent")

# %% [markdown]
# ### Dades necessaries per validació
#
# Considerant només imatges caròtides.(no bulb).
# Volem:
#  * ID patient
#  *  Mesura de IMT mean
#  *  num placa
#  * % de tipus de placa
#  *  Diametre del lumen
#  * Area placa(?)

# %%
col=[]
##ID patient
col.append('codigo_biobanco')

###Mesura IMT MEAN
col.append('gim_med_cc_d')

##numero de plaques
col.append('placas_cc_d')
## % tipus placa
col.append('lipidos_car_d')
col.append('fibrosis_car_d')
col.append('calcio_car_d')

##diametre lumen
col.append('diam_car_d')

##area placa
col.append('area_car_d')

# %%
col
# Out:
# ['codigo_biobanco',
#  'gim_med_cc_d',
#  'placas_cc_d',
#  'lipidos_car_d',
#  'fibrosis_car_d',
#  'calcio_car_d',
#  'diam_car_d',
#  'area_car_d']

# %%
gim_med_car_d
placas_car_d ## num placas
clasif_car_d ## tipus (1,2,3,4,5) depenent percentatge composicio
grado_car_d ## grau estenosis placa. Simplement classificaio segons percentatge
sisto_car_d ## buit
diasto_car_d ## buit 
ratio_car_d ## buit

diam_car_d
area_car_d
lipidos_car_d
fibrosis_car_d
calcio_car_d

# %% [markdown]
# ### Dubtes
#
# * Diferència cc i car
# * Com gestionem d i i a les imatges?
# * Què és `max_com_d`, `max_int_d`... (màxima amplitud?)--> diametre
# * Diferència `max_com_d` i `diam_car_d, diam_car_i,  diam_car_mitja`. Perquè només d'aquests 3?

# %%
col
# Out:
# ['codigo_biobanco',
#  'gim_med_cc_d',
#  'placas_cc_d',
#  'lipidos_car_d',
#  'fibrosis_car_d',
#  'calcio_car_d',
#  'diam_car_d',
#  'area_car_d']

# %% [markdown]
# ### Columnes per validació:

# %%
['codigo_biobanco',
 'gim_med_cc_d',
 'placas_cc_d',
 'lipidos_cc_d',
 'fibrosis_cc_d',
 'calcio_cc_d',
 'diam_car_d',
 'area_car_d',
 'gim_med_cc_i',
 'placas_cc_i',
 'lipidos_cc_i',
 'fibrosis_cc_i',
 'calcio_cc_i',
 'diam_car_i',
 'area_car_i']
# Out:
# ['codigo_biobanco',
#  'gim_med_cc_d',
#  'placas_cc_d',
#  'lipidos_car_d',
#  'fibrosis_car_d',
#  'calcio_car_d',
#  'diam_car_d',
#  'area_car_d',
#  'gim_med_cc_i',
#  'placas_cc_i',
#  'lipidos_car_i',
#  'fibrosis_car_i',
#  'calcio_car_i',
#  'diam_car_i',
#  'area_car_i']

# %% [markdown]
# ## Categories per anàlisis de correlació i prediccions :

# %% [markdown]
#  * vhc:
#
# Virus de la Hepatitis C
#
#  * comorbilidad:
#
# La presencia de uno o más trastornos (o enfermedades) además de la enfermedad o trastorno primario.
# El efecto de estos trastornos o enfermedades adicionales.
# En medicina, la comorbilidad describe el efecto de una enfermedad o enfermedades en un paciente cuya enfermedad primaria es otra distinta. Actualmente no existe un método aceptado para cuantificar este tipo de comorbilidad.
#
#  * ITB:
#
# Índice tobillo/brazo.
#
#  * IMC:
#
# Índice masa corporal
#
#  * HDL:
#
# High-density lipoproteins (colesterol "bo")
#
#  * LDL:
#
# Low-density lipoproteins (colesterol "dolent")
#
#  * Dislipidemia:
#
# Las dislipidemias o dislipemias son una serie de diversas condiciones patológicas cuyo único elemento común es una alteración del metabolismo de los lípidos, con su consecuente alteración de las concentraciones de lípidos y lipoproteínas en la sangre. En algunos países se le conoce como dislipemia pudiéndose usar ambos términos como sinónimos.
#
# Una primera forma de clasificarlas podría ser en:
#
# Primarias, es decir, no asociada a otras enfermedades. Generalmente de origen genético y transmisión familiar (hereditarias), es la forma menos frecuente.
#
# Secundarias, es decir vinculadas a otras entidades patológicas, como por ejemplo:
#
# diabetes
# hipotiroidismo
# obesidad patológica
# síndrome metabólico

# %% [markdown]
# old:
#
# "codigo_biobanco", "sexo", "t_comorbilidad_exploracion_edad", "raza" , "vhc", "colesterol_total2", "colesterol_hdl2", "colesterol_ldl2", "trigliceridos2", "glucosa2", "t_comorbilidad_exploracion_tabaco", "t_comorbilidad_exploracion_alcohol", "t_comorbilidad_exploracion_diabetes", "t_comorbilidad_exploracion_hipertenso", "t_comorbilidad_exploracion_dislipemico", "t_comorbilidad_exploracion_peso",  "tipo_evento_cv", "edad_paciente_evento", "muerte_paciente", "causa_muerta", "causa_muerte_cardiovascular", "causa_muerte_no_cardiovascular"

# %% [markdown]
# ### TODO
# - estudiar correlació entre tipus de placa (predominant lipidica etc...) amb factors de risc
